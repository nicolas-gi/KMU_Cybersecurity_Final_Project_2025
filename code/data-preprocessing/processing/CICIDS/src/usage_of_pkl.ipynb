# %% [markdown]
# # How to use the `*.pkl` files
#
# ### Dependencies:
# ```python
# import joblib
# ```
#
# ### Loading:
# ```python
# scaler  = joblib.load("scaler.pkl")
# pca     = joblib.load("ipca.pkl")
# ```
#
# ### Data Transformation:
# ```python
# X_scaled = scaler.transform(data)
# X_pca    = pca.transform(X_scaled)
# ```
#
# Notes:<br>
# - Always apply scaling first, then PCA
# - Input data must match the feature count and value distribution used during training
